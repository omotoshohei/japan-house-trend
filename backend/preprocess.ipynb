# %%
import pandas as pd
import numpy as np

# %%
#download from "https://www.reinfolib.mlit.go.jp/realEstatePrices/""
df = pd.read_csv('../raw_data/tokyo_20071_20234.csv', encoding="cp932", on_bad_lines='skip')

# %%
df = df.drop(columns=['市区町村コード'])
df = df.drop(columns=['価格情報区分'])
df = df.drop(columns=['建物の構造'])
df = df.drop(columns=['用途'])
df = df.drop(columns=['今後の利用目的'])
df = df.drop(columns=['都市計画'])
df = df.drop(columns=['建ぺい率（％）'])
df = df.drop(columns=['容積率（％）'])
df = df.drop(columns=['改装'])
df = df.drop(columns=['取引の事情等'])

# %%
df.head()
# Out:
#          種類 都道府県名   市区町村名 地区名 最寄駅：名称 最寄駅：距離（分）  取引価格（総額）   間取り  面積（㎡）    建築年  \
# 0  中古マンション等   千葉県  千葉市中央区  新宿     千葉        11  36000000  ３ＬＤＫ     90  2005年
# 1  中古マンション等   千葉県  千葉市中央区  新宿   千葉中央         4  37000000  ３ＬＤＫ     90  2007年
# 2  中古マンション等   千葉県  千葉市中央区  新宿    NaN       NaN  27000000  ３ＬＤＫ     75  2002年
# 3  中古マンション等   千葉県  千葉市中央区  登戸    西千葉         9  50000000  ４ＬＤＫ    145  1989年
# 4  中古マンション等   千葉県  千葉市中央区  登戸    西千葉         7  40000000  ３ＬＤＫ     85  2008年
#
#          取引時期
# 0  2021年第1四半期
# 1  2021年第1四半期
# 2  2021年第1四半期
# 3  2021年第1四半期
# 4  2021年第1四半期

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56337 entries, 0 to 56336
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   種類         56337 non-null  object
#  1   都道府県名      56337 non-null  object
#  2   市区町村名      56337 non-null  object
#  3   地区名        56337 non-null  object
#  4   最寄駅：名称     56148 non-null  object
#  5   最寄駅：距離（分）  54366 non-null  object
#  6   取引価格（総額）   56337 non-null  int64
#  7   間取り        54872 non-null  object
#  8   面積（㎡）      56337 non-null  int64
#  9   建築年        54290 non-null  object
#  10  取引時期       56337 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 4.7+ MB

# %%
df['取引価格（総額）'] = df['取引価格（総額）']/10000

# %%
df['取引時期（年）'] = df['取引時期'].str[:4]

# %%
# Get the current year
current_year = pd.Timestamp.now().year

# %%
# Step 1: Remove '年' character
df['建築年'] = df['建築年'].str.replace('年', '')

# Step 2: Drop rows with the value '戦前'
df = df[df['建築年'] != '戦前']

# Step 3: Convert to numeric, coercing errors to NaN
df['建築年'] = pd.to_numeric(df['建築年'], errors='coerce')

# Step 4: Fill NaN values with a placeholder or drop them
df['建築年'].fillna(0, inplace=True)  # Example: Fill with 0, or you can choose to drop these rows

# Get the current year
current_year = pd.Timestamp.now().year

# Step 5: Calculate the age of the building and add as new column '築年数'
df['築年数'] = current_year - df['建築年'].astype(int)

# %%
df.head()
# Out:
#          種類 都道府県名   市区町村名 地区名 最寄駅：名称 最寄駅：距離（分）  取引価格（総額）   間取り  面積（㎡）     建築年  \
# 0  中古マンション等   千葉県  千葉市中央区  新宿     千葉        11    3600.0  ３ＬＤＫ     90  2005.0
# 1  中古マンション等   千葉県  千葉市中央区  新宿   千葉中央         4    3700.0  ３ＬＤＫ     90  2007.0
# 2  中古マンション等   千葉県  千葉市中央区  新宿    NaN       NaN    2700.0  ３ＬＤＫ     75  2002.0
# 3  中古マンション等   千葉県  千葉市中央区  登戸    西千葉         9    5000.0  ４ＬＤＫ    145  1989.0
# 4  中古マンション等   千葉県  千葉市中央区  登戸    西千葉         7    4000.0  ３ＬＤＫ     85  2008.0
#
#          取引時期 取引時期（年）  築年数
# 0  2021年第1四半期    2021   19
# 1  2021年第1四半期    2021   17
# 2  2021年第1四半期    2021   22
# 3  2021年第1四半期    2021   35
# 4  2021年第1四半期    2021   16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56304 entries, 0 to 56336
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   種類         56304 non-null  object
#  1   都道府県名      56304 non-null  object
#  2   市区町村名      56304 non-null  object
#  3   地区名        56304 non-null  object
#  4   最寄駅：名称     56115 non-null  object
#  5   最寄駅：距離（分）  54333 non-null  object
#  6   取引価格（総額）   56304 non-null  float64
#  7   間取り        54839 non-null  object
#  8   面積（㎡）      56304 non-null  int64
#  9   建築年        56304 non-null  float64
#  10  取引時期       56304 non-null  object
#  11  取引時期（年）    56304 non-null  object
#  12  築年数        56304 non-null  int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.0+ MB

# %%
df['取引時期（年）'] = df['取引時期（年）'].astype(int)
df['建築年'] = df['建築年'].astype(int)

# %%
df.head()
# Out:
#          種類 都道府県名   市区町村名 地区名 最寄駅：名称 最寄駅：距離（分）  取引価格（総額）   間取り  面積（㎡）   建築年  \
# 0  中古マンション等   千葉県  千葉市中央区  新宿     千葉        11    3600.0  ３ＬＤＫ     90  2005
# 1  中古マンション等   千葉県  千葉市中央区  新宿   千葉中央         4    3700.0  ３ＬＤＫ     90  2007
# 2  中古マンション等   千葉県  千葉市中央区  新宿    NaN       NaN    2700.0  ３ＬＤＫ     75  2002
# 3  中古マンション等   千葉県  千葉市中央区  登戸    西千葉         9    5000.0  ４ＬＤＫ    145  1989
# 4  中古マンション等   千葉県  千葉市中央区  登戸    西千葉         7    4000.0  ３ＬＤＫ     85  2008
#
#          取引時期  取引時期（年）  築年数
# 0  2021年第1四半期     2021   19
# 1  2021年第1四半期     2021   17
# 2  2021年第1四半期     2021   22
# 3  2021年第1四半期     2021   35
# 4  2021年第1四半期     2021   16

# %%
df['建築年'] = df['建築年'].astype(int)

# %%
df.to_csv("../data/chiba_20071_20234_preprocessed.csv", index=False, encoding='utf-8-sig')

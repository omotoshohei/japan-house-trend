# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib
from matplotlib.ticker import MaxNLocator

# %%
df_tokyo = pd.read_csv('../data/tokyo_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')
# Out:
# /var/folders/_n/cr9xqtgn70g_tclcyk9hd0nw0000gn/T/ipykernel_9350/900451068.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tokyo = pd.read_csv('../data/tokyo_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')

# %%
df_chiba = pd.read_csv('../data/chiba_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')

# %%
room_list = ["ALL","４ＬＤＫ","３ＬＤＫ", "２ＬＤＫ", "１ＬＤＫ", "１Ｋ"]  # Include all room types and an option for all

# %%
chiba_area_list = df_chiba["市区町村名"].unique()
# Out:
# array(['千葉市中央区', '千葉市花見川区', '千葉市稲毛区', '千葉市若葉区', '千葉市緑区', '千葉市美浜区', '市川市',
#        '船橋市', '館山市', '木更津市', '松戸市', '野田市', '茂原市', '成田市', '佐倉市', '東金市',
#        '習志野市', '柏市', '勝浦市', '市原市', '流山市', '八千代市', '我孫子市', '鴨川市', '鎌ケ谷市',
#        '君津市', '富津市', '浦安市', '四街道市', '袖ケ浦市', '八街市', '印西市', '白井市', '富里市',
#        '南房総市', '山武市', 'いすみ市', '大網白里市', '印旛郡酒々井町', '山武郡横芝光町', '長生郡一宮町',
#        '長生郡白子町', '長生郡長柄町', '夷隅郡御宿町', '安房郡鋸南町'], dtype=object)

# %%
# Begin HTML structure
html_output = ""

for area in chiba_area_list:
        html_output += f"""
            <section class="posts">
                <div class="w-container">
                    <h2 class="heading">
                        {area} <span>千葉県</span>
                    </h2>
                    <div class="posts-container">
                        <article class="post">
                            <figure onclick="openModal('{area}_ALL')">
                                <img src="../../img/tool/house-trend/chiba_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} All</h3>
                            <!-- The Modal -->
                            <div id="{area}_ALL" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_ALL')">&times;</span>
                                    <img src="../../img/tool/house-trend/chiba_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_３ＬＤＫ')">
                                <img src="../../img/tool/house-trend/chiba_{area}_３ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（３ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ３ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_３ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_３ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/chiba_{area}_３ＬＤＫ_jp.png" alt="３ＬＤＫ" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_２ＬＤＫ')">
                                <img src="../../img/tool/house-trend/chiba_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ２ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_２ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_２ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/chiba_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１ＬＤＫ')">
                                <img src="../../img/tool/house-trend/chiba_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('modalAll')">&times;</span>
                                    <img src="../../img/tool/house-trend/chiba_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１Ｋ')">
                                <img src="../../img/tool/house-trend/chiba_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １Ｋ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１Ｋ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_１Ｋ')">&times;</span>
                                    <img src="../../img/tool/house-trend/chiba_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                    </div><!--posts-container-->
                </div><!--w-container-->
            </section>
       """

# To see the result you can print html_output or save it to a file
print(html_output)
# Out:
#             <section class="posts">
#                 <div class="w-container">
#                     <h2 class="heading">
#                         千葉市中央区 <span>千葉県</span>
#                     </h2>
#                     <div class="posts-container">
#                         <article class="post">
#                             <figure onclick="openModal('千葉市中央区_ALL')">
#                                 <img src="../../img/tool/house-trend/chiba_千葉市中央区_ALL_jp.png" alt="千葉市中央区の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
#                             </figure>
#                             <h3>千葉市中央区 All</h3>
#                             <!-- The Modal -->
#                             <div id="千葉市中央区_ALL" class="modal">
#                                 <div class="modal-content">
#                                     <span class="close" onclick="closeModal('千葉市中央区_ALL')">&times;</span>
# ...

# %% [markdown]
# # Kanagawa

# %%
df_kanagawa = pd.read_csv('../data/kanagawa_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')

# %%
kanagawa_area_list = df_kanagawa["市区町村名"].unique()

# %%
# Begin HTML structure
html_output = ""

for area in kanagawa_area_list:
        html_output += f"""
            <section class="posts">
                <div class="w-container">
                    <h2 class="heading">
                        {area} <span>神奈川県</span>
                    </h2>
                    <div class="posts-container">
                        <article class="post">
                            <figure onclick="openModal('{area}_ALL')">
                                <img src="../../img/tool/house-trend/kanagawa_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} All</h3>
                            <!-- The Modal -->
                            <div id="{area}_ALL" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_ALL')">&times;</span>
                                    <img src="../../img/tool/house-trend/kanagawa_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_３ＬＤＫ')">
                                <img src="../../img/tool/house-trend/kanagawa_{area}_３ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（３ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ３ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_３ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_３ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/kanagawa_{area}_３ＬＤＫ_jp.png" alt="３ＬＤＫ" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_２ＬＤＫ')">
                                <img src="../../img/tool/house-trend/kanagawa_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ２ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_２ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_２ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/kanagawa_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１ＬＤＫ')">
                                <img src="../../img/tool/house-trend/kanagawa_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('modalAll')">&times;</span>
                                    <img src="../../img/tool/house-trend/kanagawa_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１Ｋ')">
                                <img src="../../img/tool/house-trend/kanagawa_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １Ｋ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１Ｋ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_１Ｋ')">&times;</span>
                                    <img src="../../img/tool/house-trend/kanagawa_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                    </div><!--posts-container-->
                </div><!--w-container-->
            </section>
       """

# To see the result you can print html_output or save it to a file
print(html_output)
# Out:
#             <section class="posts">
#                 <div class="w-container">
#                     <h2 class="heading">
#                         横浜市鶴見区 <span>神奈川県</span>
#                     </h2>
#                     <div class="posts-container">
#                         <article class="post">
#                             <figure onclick="openModal('横浜市鶴見区_ALL')">
#                                 <img src="../../img/tool/house-trend/kanagawa_横浜市鶴見区_ALL_jp.png" alt="横浜市鶴見区の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
#                             </figure>
#                             <h3>横浜市鶴見区 All</h3>
#                             <!-- The Modal -->
#                             <div id="横浜市鶴見区_ALL" class="modal">
#                                 <div class="modal-content">
#                                     <span class="close" onclick="closeModal('横浜市鶴見区_ALL')">&times;</span>
# ...

# %% [markdown]
# # Osaka

# %%
df_osaka = pd.read_csv('../data/osaka_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')
# Out:
# /var/folders/_n/cr9xqtgn70g_tclcyk9hd0nw0000gn/T/ipykernel_9350/922846992.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_osaka = pd.read_csv('../data/osaka_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')

# %%
osaka_area_list = df_osaka["市区町村名"].unique()

# %%
# Begin HTML structure
html_output = ""

for area in osaka_area_list:
        html_output += f"""
            <section class="posts">
                <div class="w-container">
                    <h2 class="heading">
                        {area} <span>大阪府</span>
                    </h2>
                    <div class="posts-container">
                        <article class="post">
                            <figure onclick="openModal('{area}_ALL')">
                                <img src="../../img/tool/house-trend/osaka_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} All</h3>
                            <!-- The Modal -->
                            <div id="{area}_ALL" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_ALL')">&times;</span>
                                    <img src="../../img/tool/house-trend/osaka_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_３ＬＤＫ')">
                                <img src="../../img/tool/house-trend/osaka_{area}_３ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（３ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ３ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_３ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_３ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/osaka_{area}_３ＬＤＫ_jp.png" alt="３ＬＤＫ" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_２ＬＤＫ')">
                                <img src="../../img/tool/house-trend/osaka_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ２ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_２ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_２ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/osaka_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１ＬＤＫ')">
                                <img src="../../img/tool/house-trend/osaka_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('modalAll')">&times;</span>
                                    <img src="../../img/tool/house-trend/osaka_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１Ｋ')">
                                <img src="../../img/tool/house-trend/osaka_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １Ｋ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１Ｋ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_１Ｋ')">&times;</span>
                                    <img src="../../img/tool/house-trend/osaka_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                    </div><!--posts-container-->
                </div><!--w-container-->
            </section>
       """

# To see the result you can print html_output or save it to a file
print(html_output)
# Out:
#             <section class="posts">
#                 <div class="w-container">
#                     <h2 class="heading">
#                         大阪市都島区 <span>大阪府</span>
#                     </h2>
#                     <div class="posts-container">
#                         <article class="post">
#                             <figure onclick="openModal('大阪市都島区_ALL')">
#                                 <img src="../../img/tool/house-trend/osaka_大阪市都島区_ALL_jp.png" alt="大阪市都島区の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
#                             </figure>
#                             <h3>大阪市都島区 All</h3>
#                             <!-- The Modal -->
#                             <div id="大阪市都島区_ALL" class="modal">
#                                 <div class="modal-content">
#                                     <span class="close" onclick="closeModal('大阪市都島区_ALL')">&times;</span>
# ...

# %% [markdown]
# # Aichi

# %%
df_aichi = pd.read_csv('../data/aichi_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')

# %%
aichi_area_list = df_aichi["市区町村名"].unique()

# %%
# Begin HTML structure
html_output = ""

for area in aichi_area_list:
        html_output += f"""
            <section class="posts">
                <div class="w-container">
                    <h2 class="heading">
                        {area} <span>愛知県</span>
                    </h2>
                    <div class="posts-container">
                        <article class="post">
                            <figure onclick="openModal('{area}_ALL')">
                                <img src="../../img/tool/house-trend/aichi_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} All</h3>
                            <!-- The Modal -->
                            <div id="{area}_ALL" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_ALL')">&times;</span>
                                    <img src="../../img/tool/house-trend/aichi_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_３ＬＤＫ')">
                                <img src="../../img/tool/house-trend/aichi_{area}_３ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（３ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ３ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_３ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_３ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/aichi_{area}_３ＬＤＫ_jp.png" alt="３ＬＤＫ" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_２ＬＤＫ')">
                                <img src="../../img/tool/house-trend/aichi_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ２ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_２ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_２ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/aichi_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１ＬＤＫ')">
                                <img src="../../img/tool/house-trend/aichi_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('modalAll')">&times;</span>
                                    <img src="../../img/tool/house-trend/aichi_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１Ｋ')">
                                <img src="../../img/tool/house-trend/aichi_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １Ｋ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１Ｋ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_１Ｋ')">&times;</span>
                                    <img src="../../img/tool/house-trend/aichi_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                    </div><!--posts-container-->
                </div><!--w-container-->
            </section>
       """

# To see the result you can print html_output or save it to a file
print(html_output)
# Out:
#             <section class="posts">
#                 <div class="w-container">
#                     <h2 class="heading">
#                         名古屋市千種区 <span>愛知県</span>
#                     </h2>
#                     <div class="posts-container">
#                         <article class="post">
#                             <figure onclick="openModal('名古屋市千種区_ALL')">
#                                 <img src="../../img/tool/house-trend/aichi_名古屋市千種区_ALL_jp.png" alt="名古屋市千種区の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
#                             </figure>
#                             <h3>名古屋市千種区 All</h3>
#                             <!-- The Modal -->
#                             <div id="名古屋市千種区_ALL" class="modal">
#                                 <div class="modal-content">
#                                     <span class="close" onclick="closeModal('名古屋市千種区_ALL')">&times;</span>
# ...

# %% [markdown]
# # Saitama

# %%
df_saitama = pd.read_csv('../data/saitama_20071_20234_preprocessed.csv', encoding="utf-8", on_bad_lines='skip')

# %%
saitama_area_list = df_saitama["市区町村名"].unique()

# %%
# Begin HTML structure
html_output = ""

for area in saitama_area_list:
        html_output += f"""
            <section class="posts">
                <div class="w-container">
                    <h2 class="heading">
                        {area} <span>埼玉県</span>
                    </h2>
                    <div class="posts-container">
                        <article class="post">
                            <figure onclick="openModal('{area}_ALL')">
                                <img src="../../img/tool/house-trend/saitama_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} All</h3>
                            <!-- The Modal -->
                            <div id="{area}_ALL" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_ALL')">&times;</span>
                                    <img src="../../img/tool/house-trend/saitama_{area}_ALL_jp.png" alt="{area}の中古不動産価格の推移（すべて）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_３ＬＤＫ')">
                                <img src="../../img/tool/house-trend/saitama_{area}_３ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（３ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ３ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_３ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_３ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/saitama_{area}_３ＬＤＫ_jp.png" alt="３ＬＤＫ" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_２ＬＤＫ')">
                                <img src="../../img/tool/house-trend/saitama_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} ２ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_２ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_２ＬＤＫ')">&times;</span>
                                    <img src="../../img/tool/house-trend/saitama_{area}_２ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（２ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１ＬＤＫ')">
                                <img src="../../img/tool/house-trend/saitama_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １ＬＤＫ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１ＬＤＫ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('modalAll')">&times;</span>
                                    <img src="../../img/tool/house-trend/saitama_{area}_１ＬＤＫ_jp.png" alt="{area}の中古不動産価格の推移（１ＬＤＫ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                        <article class="post">
                            <figure onclick="openModal('{area}_１Ｋ')">
                                <img src="../../img/tool/house-trend/saitama_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" width="300" height="225" style="cursor: pointer;">
                            </figure>
                            <h3>{area} １Ｋ</h3>
                            <!-- The Modal -->
                            <div id="{area}_１Ｋ" class="modal">
                                <div class="modal-content">
                                    <span class="close" onclick="closeModal('{area}_１Ｋ')">&times;</span>
                                    <img src="../../img/tool/house-trend/saitama_{area}_１Ｋ_jp.png" alt="{area}の中古不動産価格の推移（１Ｋ）" style="width:100%">
                                </div>
                            </div>
                        </article>

                    </div><!--posts-container-->
                </div><!--w-container-->
            </section>
       """

# To see the result you can print html_output or save it to a file
print(html_output)
# Out:
#             <section class="posts">
#                 <div class="w-container">
#                     <h2 class="heading">
#                         さいたま市西区 <span>埼玉県</span>
#                     </h2>
#                     <div class="posts-container">
#                         <article class="post">
#                             <figure onclick="openModal('さいたま市西区_ALL')">
#                                 <img src="../../img/tool/house-trend/saitama_さいたま市西区_ALL_jp.png" alt="さいたま市西区の中古不動産価格の推移（すべて）" width="300" height="225" style="cursor: pointer;">
#                             </figure>
#                             <h3>さいたま市西区 All</h3>
#                             <!-- The Modal -->
#                             <div id="さいたま市西区_ALL" class="modal">
#                                 <div class="modal-content">
#                                     <span class="close" onclick="closeModal('さいたま市西区_ALL')">&times;</span>
# ...
